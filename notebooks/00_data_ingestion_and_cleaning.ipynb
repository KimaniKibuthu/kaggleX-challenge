# %% [markdown]
# # Data Ingestion and Cleaning
# In this notebook we go through the data and clean it.

# %% [markdown]
# ## Import the necessary libraries

# %%
# Set configuration for notebook
import os

os.chdir("c:\\Users\\Spectra\\kaggleX-challenge")
os.getcwd()
# Out:
# 'c:\\Users\\Spectra\\kaggleX-challenge'

# %%
import pandas as pd

# %% [markdown]
# ## Data Ingestion

# %%
# Load the data
train_df = pd.read_csv("data/train.csv")
test_df = pd.read_csv("data/test.csv")
submission_df = pd.read_csv("data/sample_submission.csv")

# %%
# View train 
train_df.head()
# Out:
#    id    brand          model  model_year  milage fuel_type  \
# 0   0     Ford   F-150 Lariat        2018   74349  Gasoline
# 1   1      BMW          335 i        2007   80000  Gasoline
# 2   2   Jaguar      XF Luxury        2009   91491  Gasoline
# 3   3      BMW   X7 xDrive40i        2022    2437    Hybrid
# 4   4  Pontiac  Firebird Base        2001  111000  Gasoline
#
#                                               engine  \
# 0      375.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 1  300.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
# 2       300.0HP 4.2L 8 Cylinder Engine Gasoline Fuel
# 3  335.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
# 4      200.0HP 3.8L V6 Cylinder Engine Gasoline Fuel
#
#                      transmission ext_col int_col       accident clean_title  \
# 0                    10-Speed A/T    Blue    Gray  None reported         Yes
# 1                     6-Speed M/T   Black   Black  None reported         Yes
# 2                     6-Speed A/T  Purple   Beige  None reported         Yes
# 3  Transmission w/Dual Shift Mode    Gray   Brown  None reported         Yes
# 4                             A/T   White   Black  None reported         Yes
#
#    price
# 0  11000
# 1   8250
# 2  15000
# 3  63500
# 4   7850

# %% [markdown]
# ## Data exploration

# %%
# View info
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54273 entries, 0 to 54272
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            54273 non-null  int64
#  1   brand         54273 non-null  object
#  2   model         54273 non-null  object
#  3   model_year    54273 non-null  int64
#  4   milage        54273 non-null  int64
#  5   fuel_type     54273 non-null  object
#  6   engine        54273 non-null  object
#  7   transmission  54273 non-null  object
#  8   ext_col       54273 non-null  object
#  9   int_col       54273 non-null  object
#  10  accident      54273 non-null  object
#  11  clean_title   54273 non-null  object
#  12  price         54273 non-null  int64
# dtypes: int64(4), object(9)
# memory usage: 5.4+ MB

# %% [markdown]
# There are no missing values

# %% [markdown]
# Let's check for duplicates

# %%
# Check for duplicates
train_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There are no duplicates.
#
#
# The next process is to clean up for the data types.

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# **Check Fuel Type**

# %%
train_df["fuel_type"].value_counts()
# Out:
# fuel_type
# Gasoline          49439
# Hybrid             1766
# E85 Flex Fuel      1479
# Diesel             1109
# –                   294
# Plug-In Hybrid      182
# not supported         4
# Name: count, dtype: int64

# %% [markdown]
# Let's check for the - and not supported and see what these vehicles are

# %%
# Not supported and - cars
not_supported_df = train_df[train_df['fuel_type'].isin(['–', 'not supported'])]
not_supported_df.sample(10)
# Out:
#           id      brand                       model  model_year  milage  \
# 41628  41628      Dodge         Dakota SLT Quad Cab        1999  130921
# 15764  15764       Ford    Mustang EcoBoost Premium        2019   34000
# 33815  33815      Dodge             Challenger SRT8        2010  106500
# 45467  45467   Cadillac                DeVille Base        1994  103000
# 46268  46268       Ford    Mustang EcoBoost Premium        2017   34000
# 3083    3083     Jaguar             XJ6 Vanden Plas        1995   70000
# 45716  45716      Mazda             MX-5 Miata Base        2008   46873
# 43158  43158  Chevrolet  1500 Cheyenne Extended Cab        1996   43000
# 48616  48616      Dodge              Challenger R/T        2016   73000
# 6671    6671    Porsche       911 Carrera Cabriolet        1995   94000
#
#       fuel_type engine transmission ext_col int_col  \
# 41628         –      –          A/T   Black    Gray
# 15764         –      –          A/T    Blue    Gray
# 33815         –      –  6-Speed M/T   White   White
# 45467         –      –          A/T    Blue   Beige
# 46268         –      –  6-Speed M/T    Blue    Gray
# 3083          –      –          A/T   White   Black
# 45716         –      –          A/T   Green   Beige
# 43158         –      –          A/T   White    Gray
# 48616         –      –          A/T   Black   Black
# 6671          –      –  6-Speed M/T    Blue    Gray
#
#                                      accident clean_title  price
# 41628  At least 1 accident or damage reported         Yes   4500
# 15764  At least 1 accident or damage reported         Yes  32500
# 33815  At least 1 accident or damage reported         Yes  22500
# 45467                           None reported         Yes  12500
# 46268  At least 1 accident or damage reported         Yes  25000
# 3083                            None reported         Yes  14995
# 45716                           None reported         Yes  11500
# 43158                           None reported         Yes  20000
# 48616                           None reported         Yes  17500
# 6671                            None reported         Yes  22500

# %% [markdown]
# For the - values we substitute them with unknown. For the not supported we extract from the engine.

# %%
train_df[train_df['fuel_type'].isin(['not supported'])]
# Out:
#           id   brand            model  model_year  milage      fuel_type  \
# 1069    1069  Toyota       Mirai Base        2016   40000  not supported
# 9621    9621  Toyota    Mirai Limited        2023   29553  not supported
# 11441  11441  Toyota    Mirai Limited        2018   40000  not supported
# 21771  21771  Nissan  Armada Platinum        2017   92000  not supported
#
#                                              engine  \
# 1069           151.0HP Electric Motor Hydrogen Fuel
# 9621           182.0HP Electric Motor Hydrogen Fuel
# 11441          182.0HP Electric Motor Hydrogen Fuel
# 21771  390.0HP 5.6L 8 Cylinder Engine Gasoline Fuel
#
#                          transmission ext_col int_col       accident  \
# 1069                              A/T  Silver   Black  None reported
# 9621                              A/T  Silver    Gray  None reported
# 11441                             A/T  Silver    Gray  None reported
# 21771  Transmission w/Dual Shift Mode    Gray   Black  None reported
#
#       clean_title  price
# 1069          Yes  14000
# 9621          Yes   9995
# 11441         Yes   7500
# 21771         Yes  20900

# %%
def extract_fuel_type(text):
    text = text.split()
    return text[-2]

def clean_dash_values(df, column):
    df[column] = df[column].replace('–', 'Unknown')
    return df

# %%
# Change the not supported
train_df['fuel_type'] = train_df.apply(
    lambda row: extract_fuel_type(row['engine']) if row['fuel_type'] == 'not supported' else row['fuel_type'],
    axis=1
)

# %%
# Deal with the dash values

train_df = clean_dash_values(train_df, 'fuel_type')

# %%
train_df["fuel_type"].value_counts()
# Out:
# fuel_type
# Gasoline          49440
# Hybrid             1766
# E85 Flex Fuel      1479
# Diesel             1109
# Unknown             294
# Plug-In Hybrid      182
# Hydrogen              3
# Name: count, dtype: int64

# %%
# Change the not supported
test_df['fuel_type'] = test_df.apply(
    lambda row: extract_fuel_type(row['engine']) if row['fuel_type'] == 'not supported' else row['fuel_type'],
    axis=1
)

test_df = clean_dash_values(test_df, 'fuel_type')

# %% [markdown]
# **Check Brand**

# %%
train_df["brand"].value_counts()
# Out:
# brand
# BMW              7369
# Ford             6706
# Mercedes-Benz    5087
# Chevrolet        4424
# Audi             2922
# Porsche          2627
# Toyota           2315
# Lexus            2257
# Jeep             2247
# Land             1995
# Cadillac         1565
# Nissan           1252
# GMC              1076
# Dodge            1011
# RAM               966
# INFINITI          957
# Lincoln           767
# Mazda             748
# Subaru            739
# Hyundai           694
# Jaguar            661
# Volkswagen        628
# Honda             624
# Acura             580
# Kia               526
# Volvo             452
# MINI              364
# Maserati          293
# Bentley           284
# Chrysler          258
# Genesis           249
# Buick             228
# Mitsubishi        182
# Hummer            176
# Pontiac           149
# Alfa              144
# Rolls-Royce       142
# Lamborghini       122
# Tesla             110
# Ferrari            87
# Saturn             58
# Scion              53
# Aston              50
# McLaren            43
# Rivian             27
# Mercury            20
# FIAT               16
# Lotus              12
# Suzuki              4
# Maybach             3
# Lucid               2
# Plymouth            1
# Bugatti             1
# Name: count, dtype: int64

# %% [markdown]
# Brand looks clean

# %% [markdown]
# **Check accident**

# %%
train_df["accident"].value_counts()
# Out:
# accident
# None reported                             39896
# At least 1 accident or damage reported    14377
# Name: count, dtype: int64

# %% [markdown]
# **Transmission**

# %%
# Check value counts
transmissions = train_df["transmission"].value_counts()

# %%
transmissions
# Out:
# transmission
# A/T                                                   16757
# 8-Speed A/T                                            7287
# Transmission w/Dual Shift Mode                         6454
# 6-Speed A/T                                            5944
# 6-Speed M/T                                            3618
# 7-Speed A/T                                            3415
# 10-Speed A/T                                           2187
# 8-Speed Automatic                                      1189
# 5-Speed A/T                                            1185
# 9-Speed A/T                                            1073
# 4-Speed A/T                                             764
# 5-Speed M/T                                             718
# CVT Transmission                                        692
# 10-Speed Automatic                                      642
# 6-Speed Automatic                                       516
# Automatic                                               441
# M/T                                                     359
# 9-Speed Automatic                                       344
# 7-Speed Automatic with Auto-Shift                       110
# 7-Speed M/T                                             104
# Automatic CVT                                            95
# 1-Speed A/T                                              60
# 8-Speed Automatic with Auto-Shift                        55
# Transmission Overdrive Switch                            54
# 7-Speed Automatic                                        41
# 6-Speed Manual                                           34
# 5-Speed Automatic                                        24
# 7-Speed Manual                                           22
# 6-Speed Automatic with Auto-Shift                        17
# 8-Speed Manual                                            9
# 4-Speed Automatic                                         8
# 7-Speed                                                   7
# –                                                         7
# 7-Speed DCT Automatic                                     6
# 1-Speed Automatic                                         6
# 6-Speed Electronically Controlled Automatic with O        6
# 10-Speed Automatic with Overdrive                         5
# 2-Speed A/T                                               5
# 6-Speed                                                   3
# 9-Speed Automatic with Auto-Shift                         2
# SCHEDULED FOR OR IN PRODUCTION                            2
# 6 Speed Mt                                                2
# CVT-F                                                     1
# F                                                         1
# Variable                                                  1
# 6 Speed At/Mt                                             1
# Name: count, dtype: int64

# %% [markdown]
# Combine the transmissions into four features namely CVT, automatic, manual and unknown

# %%
# Normalize the text
train_df['transmission'] = train_df['transmission'].str.lower()

test_df['transmission'] = test_df['transmission'].str.lower()
# Mapping for standardization and reduction
transmission_map = {
    'a/t': 'automatic',
    '8-speed a/t': 'automatic',
    'transmission w/dual shift mode': 'automatic',
    '6-speed a/t': 'automatic',
    '6-speed m/t': 'manual',
    '7-speed a/t': 'automatic',
    '10-speed a/t': 'automatic',
    '8-speed automatic': 'automatic',
    '5-speed a/t': 'automatic',
    '9-speed a/t': 'automatic',
    '4-speed a/t': 'automatic',
    '5-speed m/t': 'manual',
    'cvt transmission': 'cvt',
    '10-speed automatic': 'automatic',
    '6-speed automatic': 'automatic',
    'automatic': 'automatic',
    'm/t': 'manual',
    '9-speed automatic': 'automatic',
    '7-speed automatic with auto-shift': 'automatic',
    '7-speed m/t': 'manual',
    'automatic cvt': 'cvt',
    '1-speed a/t': 'automatic',
    '8-speed automatic with auto-shift': 'automatic',
    'transmission overdrive switch': 'automatic',
    '7-speed automatic': 'automatic',
    '6-speed manual': 'manual',
    '5-speed automatic': 'automatic',
    '7-speed manual': 'manual',
    '6-speed automatic with auto-shift': 'automatic',
    '8-speed manual': 'manual',
    '4-speed automatic': 'automatic',
    '7-speed': 'automatic',
    '–': 'unknown',
    '7-speed dct automatic': 'automatic',
    '1-speed automatic': 'automatic',
    '6-speed electronically controlled automatic with o': 'automatic',
    '10-speed automatic with overdrive': 'automatic',
    '2-speed a/t': 'automatic',
    '6-speed': 'automatic',
    '9-speed automatic with auto-shift': 'automatic',
    'scheduled for or in production': 'unknown',
    '6 speed mt': 'manual',
    'cvt-f': 'cvt',
    'f': 'unknown',
    'variable': 'cvt',
    '6 speed at/mt': 'automatic'
}

# Apply mapping
train_df['transmission'] = train_df['transmission'].replace(transmission_map)
test_df['transmission'] = test_df['transmission'].replace(transmission_map)

# %% [markdown]
# **Check color**

# %%
# Check color value counts
train_df['ext_col'].unique()
# Out:
# array(['Blue', 'Black', 'Purple', 'Gray', 'White', 'Red', 'Silver',
#        'Summit White', 'Platinum Quartz Metallic', 'Green', 'Orange',
#        'Lunar Rock', 'Red Quartz Tintcoat', 'Beige', 'Gold',
#        'Jet Black Mica', 'Delmonico Red Pearlcoat', 'Brown',
#        'Rich Garnet Metallic', 'Stellar Black Metallic', 'Yellow',
#        'Deep Black Pearl Effect', 'Metallic', 'Ice Silver Metallic',
#        'Agate Black Metallic', 'Rosso Mars Metallic', 'White Clearcoat',
#        'Santorini Black Metallic', 'DB Black Clearcoat',
#        'Snowflake White Pearl', 'Glacial White Pearl',
#        'Maximum Steel Metallic', 'Blue Caelum', 'Dark Matter Metallic',
#        '–', 'Oxford White', 'Cobra Beige Metallic',
#        'Velvet Red Pearlcoat', 'Python Green', 'Obsidian Black Metallic',
#        'Beluga Black', 'Blue Reflex Mica', 'Sparkling Silver',
#        'Black Clearcoat', 'Soul Red Crystal Metallic',
#        'Bright White Clearcoat', 'Shimmering Silver',
#        'Midnight Black Metallic', 'Cajun Red Tintcoat',
#        'Cirrus Silver Metallic', 'Blu', 'Burnished Bronze Metallic',
#        'Hellayella Clearcoat', 'Diamond Black', 'White Diamond Tri-Coat',
#        'Nebula Gray Pearl', 'Bronze Dune Metallic',
#        'Polymetal Gray Metallic', 'Nightfall Gray Metallic', 'Fuji White',
#        'Shadow Gray Metallic', 'Dark Moon Blue Metallic', 'Dark Sapphire',
#        'Firecracker Red Clearcoat', 'Black Raven',
#        'White Knuckle Clearcoat', 'Siren Red Tintcoat',
#        'Designo Magno Matte', 'Atomic Silver',
#        'Billet Silver Metallic Clearcoat', 'Ember Pearlcoat',
#        'Magnetic Black', 'Pacific Blue Metallic',
#        'Midnight Blue Metallic', 'Alta White', 'Eiger Grey',
#        'Diamond White', 'Onyx', 'Hyper Red', 'Ebony Twilight Metallic',
#        'Alpine White', 'Sonic Silver Metallic', 'Dark Ash Metallic',
#        'Volcano Grey Metallic', 'Patriot Blue Pearlcoat', 'Onyx Black',
#        'Titanium Silver', 'Granite Crystal Clearcoat Metallic',
#        'Nero Noctis', 'Silver Zynith', 'Black Cherry',
#        'Iconic Silver Metallic', 'Nero Daytona',
#        'Daytona Gray Pearl Effect', 'Dark Moss', 'Deep Crystal Blue Mica',
#        'China Blue', 'Magnetic Metallic', 'Midnight Black', 'Vega Blue',
#        'Sandstone Metallic', 'Machine Gray Metallic', 'C / C',
#        'Platinum Gray Metallic', 'Silver Ice Metallic',
#        'Carrara White Metallic', 'Black Sapphire Metallic', 'Go Mango!',
#        'White Frost Tri-Coat', 'Lizard Green', 'Santorin Black',
#        'Twilight Black', 'Gecko Pearlcoat', 'Satin Steel Metallic',
#        'Imperial Blue Metallic', 'Nautical Blue Pearl',
#        'Stone Gray Metallic', 'Quartzite Grey Metallic',
#        'Majestic Black Pearl', 'Shadow Black', 'Crimson Red Tintcoat',
#        'Silver Flare Metallic', 'Vik Black', 'Lunar Silver Metallic',
#        'Maroon', 'Redline Red', 'Iridescent Pearl Tricoat',
#        'Brilliant Silver Metallic', 'Lunar Blue Metallic', 'Matte White',
#        'Tan', 'Stormy Sea', 'Twilight Blue Metallic', 'Ibis White',
#        'Kodiak Brown Metallic', 'Crystal Black Silica',
#        'Sting Gray Clearcoat', 'Pristine White', 'Pearl White',
#        'Antimatter Blue Metallic', 'Tango Red Metallic',
#        'Crystal Black Pearl', 'Rift Metallic', 'Glacier White Metallic',
#        'Quartz White', 'Black Obsidian', 'Brilliant Black',
#        'Ruby Red Metallic Tinted Clearcoat', 'Tungsten Metallic',
#        'Magnetite Black Metallic', 'Jupiter Red', 'Glacier',
#        'Santorini Black', 'Navarre Blue',
#        'Phantom Black Pearl Effect / Black Roof',
#        'Isle of Man Green Metallic', 'Snowflake White Pearl Metallic',
#        'Brands Hatch Gray Metallic', 'Volcanic Orange', 'Liquid Platinum',
#        'Bayside Blue', 'Rapid Red Metallic Tinted Clearcoat',
#        'Majestic Plum Metallic', 'White Platinum Tri-Coat Metallic',
#        'Mosaic Black Metallic', 'Chalk', 'Black Noir Pearl',
#        'Nightfall Mica', 'Dark Gray Metallic', 'Mythos Black Metallic',
#        'Blueprint', 'Quicksilver Metallic', 'Frozen White',
#        'Lunare White Metallic', 'Verde', 'Dark Graphite Metallic',
#        'Mythos Black', 'Ebony Black', 'Ultra Black',
#        'Ingot Silver Metallic', 'Glacier Silver Metallic', 'Gun Metallic',
#        'Wind Chill Pearl', 'Anodized Blue Metallic',
#        'designo Diamond White', 'Tempest', 'Caviar',
#        'Phytonic Blue Metallic', 'Moonlight Cloud',
#        'Daytona Gray Pearl Effect w/ Black Roof', 'Bianco Isis',
#        'Carbonized Gray Metallic', 'Deep Blue Metallic',
#        'Ametrin Metallic', 'Super Black', 'Rosso Corsa', 'Blue Metallic',
#        'Iridium Metallic', 'Dark Slate Metallic',
#        'Manhattan Noir Metallic', 'Alfa White', 'Baltic Gray',
#        'Northsky Blue Metallic', 'Super White', 'Carbon Black Metallic',
#        'Horizon Blue', 'Jungle Green', 'Cayenne Red Tintcoat', 'Pink',
#        'Daytona Gray', 'Gentian Blue Metallic', 'Sangria Red',
#        'Kemora Gray Metallic', 'Magnetite Gray Metallic',
#        'Octane Red Pearlcoat', 'Custom Color', 'Ultra White',
#        'Pacific Blue', 'Ruby Flare Pearl', 'Caspian Blue',
#        'Silver Radiance', 'Carpathian Grey Premium Metallic', 'Ice',
#        'Balloon White', 'Shoreline Blue Pearl', 'Firenze Red Metallic',
#        'Remington Red Metallic', 'Orca Black Metallic',
#        'Radiant Red Metallic II', 'Mineral White', 'Glacier White',
#        'Snow White Pearl', 'Iridium Silver Metallic', 'Carpathian Grey',
#        'Mountain Air Metallic', 'Selenite Gray Metallic',
#        'Graphite Grey Metallic', 'Selenite Grey Metallic', 'Kinetic Blue',
#        'Wolf Gray', 'Star White', 'Emin White', 'Indus Silver',
#        'Matador Red Metallic', 'Portofino Gray', 'Black Forest Green',
#        'Dazzling White', 'Flame Red Clearcoat', 'Glacier Blue Metallic',
#        'Arctic White', 'Rosso', 'Silver Mist', 'Bianco Icarus Metallic',
#        'Firenze Red', 'Ironman Silver', 'Red Obsession',
#        'Magnetic Gray Metallic', 'Garnet Red Metallic',
#        'Vulcano Black Metallic', 'Magnetic Gray Clearcoat'], dtype=object)

# %%
# Check interior color value counts
train_df['int_col'].unique()
# Out:
# array(['Gray', 'Black', 'Beige', 'Brown', 'Silver', 'Jet Black', 'Mesa',
#        'White', '–', 'Red', 'Blue', 'Medium Stone', 'Ash', 'Ebony',
#        'Shara Beige', 'Tan', 'Titan Black / Quarzit', 'Global Black',
#        'Orange', 'Saddle Brown', 'Nero Ade', 'Beluga', 'Light Slate',
#        'Gold', 'Black Onyx', 'Nougat Brown', 'Camel', 'Hotspur Hide',
#        'Charcoal', 'Satin Black', 'Deep Chestnut', 'Diesel Gray / Black',
#        'White / Brown', 'AMG Black', 'Parchment', 'Shale',
#        'Canberra Beige', 'Sahara Tan', 'Ebony / Pimento', 'Rhapsody Blue',
#        'Medium Dark Slate', 'Rioja Red', 'Black / Express Red',
#        'Deep Garnet', 'Portland', 'Sandstone', 'Dark Ash', 'Deep Cypress',
#        'Black / Stone Grey', 'Chestnut', 'Navy Pier', 'Green',
#        'Giallo Taurus / Nero Ade', 'Mistral Gray / Raven', 'Dark Gray',
#        'Amber', 'Charles Blue', 'Hotspur', 'Medium Earth Gray', 'Ceramic',
#        'Kyalami Orange', 'Charcoal Black', 'Adrenaline Red', 'Walnut',
#        'Brandy', 'Black / Saddle', 'Obsidian Black', 'Oyster W/Contrast',
#        'Macchiato', 'Red / Black', 'Whisper Beige', 'Graphite', 'Yellow',
#        'Medium Light Camel', 'Slate', 'Nero', 'Ebony Black', 'Espresso',
#        'Cappuccino', 'Ivory / Ebony', 'Boulder', 'Medium Ash Gray',
#        'Platinum', 'Light Platinum / Jet Black', 'Beluga Hide',
#        'Black / Graphite', 'Canberra Beige/Black', 'Rock Gray',
#        'Dark Auburn', 'Almond Beige', 'Sand Beige', 'Black / Brown',
#        'Ice', 'Silk Beige/Espresso Brown', 'Dark Galvanized',
#        'Cobalt Blue', 'Grace White', 'Titan Black', 'Cocoa / Dune',
#        'Light Gray', 'Camel Leather', 'Light Titanium',
#        'Pimento Red w/Ebony', 'Sport', 'Oyster/Black', 'Black/Red',
#        'Ebony / Ebony Accents', 'Cloud', 'Graystone', 'BLACK',
#        'Mountain Brown', 'Linen', 'Caramel', 'Black / Gray', 'Blk',
#        'Black w/Red Stitching', 'Mocha', 'Tupelo', 'Tan/Ebony',
#        'Parchment.', 'Black/Gun Metal', 'Very Light Cashmere',
#        'Medium Pewter', 'Red/Black'], dtype=object)

# %%
# Get value from the color such as categorize the color among creating new features
# Function to categorize colors
def categorize_color(color):
    color = color.lower()
    if 'blue' in color:
        return 'Blue'
    elif 'black' in color or 'nero' in color or 'obsidian' in color:
        return 'Black'
    elif 'gray' in color or 'grey' in color or 'graphite' in color or 'pearl effect' in color:
        return 'Gray'
    elif 'white' in color or 'glacier' in color or 'snow' in color or 'chalk' in color or 'pearl' in color or 'diamond' in color:
        return 'White'
    elif 'red' in color or 'rosso' in color or 'garnet' in color or 'sangria' in color:
        return 'Red'
    elif 'silver' in color or 'metallic' in color or 'mist' in color:
        return 'Silver'
    elif 'green' in color or 'jungle' in color or 'moss' in color:
        return 'Green'
    elif 'yellow' in color:
        return 'Yellow'
    elif 'orange' in color:
        return 'Orange'
    elif 'brown' in color:
        return 'Brown'
    elif 'purple' in color or 'plum' in color:
        return 'Purple'
    elif 'gold' in color:
        return 'Gold'
    elif 'beige' in color or 'tan' in color or 'bronze' in color:
        return 'Beige'
    elif 'pink' in color:
        return 'Pink'
    else:
        return 'Other/Unknown'

# Additional feature extraction functions
def is_exotic_or_rare(color):
    rare_colors = [
        'python green', 'hellayella clearcoat', 'lizard green', 'go mango!',
        'gecko pearlcoat', 'liquid platinum', 'isle of man green metallic',
        'rapid red metallic tinted clearcoat', 'majestic plum metallic',
        'volcanic orange', 'chalk', 'sangria red', 'gentian blue metallic',
        'balloon white', 'remington red metallic'
    ]
    return 'Exotic/Rare' if color.lower() in rare_colors else 'Common'

def is_bright(color):
    bright_colors = ['white', 'yellow', 'silver', 'light', 'diamond', 'frost', 'crystal', 'snow']
    return 'Bright' if any(bright in color.lower() for bright in bright_colors) else 'Dark'

def has_metallic_finish(color):
    return 'Metallic' if 'metallic' in color.lower() else 'Non-Metallic'

def has_pearl_or_matte_finish(color):
    if 'pearl' in color.lower():
        return 'Pearlescent'
    elif 'matte' in color.lower():
        return 'Matte'
    else:
        return 'Standard'

# Apply categorizations to the DataFrame columns
train_df['categorized_ext_color'] = train_df['ext_col'].apply(categorize_color)
train_df['exotic_or_rare_ext'] = train_df['ext_col'].apply(is_exotic_or_rare)
train_df['brightness_ext'] = train_df['ext_col'].apply(is_bright)
train_df['metallic_finish_ext'] = train_df['ext_col'].apply(has_metallic_finish)
train_df['finish_ext'] = train_df['ext_col'].apply(has_pearl_or_matte_finish)


test_df['categorized_ext_color'] = test_df['ext_col'].apply(categorize_color)
test_df['exotic_or_rare_ext'] = test_df['ext_col'].apply(is_exotic_or_rare)
test_df['brightness_ext'] = test_df['ext_col'].apply(is_bright)
test_df['metallic_finish_ext'] = test_df['ext_col'].apply(has_metallic_finish)
test_df['finish_ext'] = test_df['ext_col'].apply(has_pearl_or_matte_finish)

# %%
# Function to categorize interior colors
def categorize_interior_color(color):
    color = color.lower()
    if 'black' in color or 'ebony' in color or 'nero' in color:
        return 'Black'
    elif 'gray' in color or 'grey' in color or 'ash' in color or 'slate' in color or 'pewter' in color or 'graphite' in color or 'quarzit' in color:
        return 'Gray'
    elif 'beige' in color or 'camel' in color or 'parchment' in color or 'sand' in color or 'tan' in color or 'almond' in color or 'cappuccino' in color:
        return 'Beige'
    elif 'brown' in color or 'chestnut' in color or 'saddle' in color or 'brandy' in color or 'mocha' in color or 'auburn' in color or 'espresso' in color:
        return 'Brown'
    elif 'white' in color or 'platinum' in color or 'light' in color or 'ivory' in color or 'linen' in color or 'macchiato' in color or 'whisper' in color:
        return 'White'
    elif 'red' in color or 'garnet' in color or 'hotspur' in color or 'adrenaline' in color or 'rioja' in color:
        return 'Red'
    elif 'blue' in color or 'navy' in color or 'cobalt' in color or 'rhapsody' in color or 'charles' in color:
        return 'Blue'
    elif 'green' in color or 'cypress' in color:
        return 'Green'
    elif 'gold' in color or 'amber' in color:
        return 'Gold'
    elif 'orange' in color or 'mesa' in color or 'kyalami' in color:
        return 'Orange'
    elif 'silver' in color:
        return 'Silver'
    elif 'yellow' in color:
        return 'Yellow'
    else:
        return 'Other/Unknown'

# Additional feature extraction functions
def is_luxurious(color):
    luxury_colors = [
        'jet black', 'nero ade', 'beluga', 'hotspur hide', 'amg black', 'saddle brown',
        'obsidian black', 'pimento red w/ebony', 'titan black / quarzit', 'whisper beige',
        'macchiato', 'beluga hide', 'silk beige/espresso brown', 'pimento red'
    ]
    return 'Luxurious' if color.lower() in luxury_colors else 'Standard'

def is_light_or_dark(color):
    light_colors = ['white', 'beige', 'ivory', 'light', 'platinum', 'linen', 'whisper']
    return 'Light' if any(light in color.lower() for light in light_colors) else 'Dark'

def is_two_tone(color):
    return 'Two-Tone' if '/' in color or '-' in color else 'Single-Tone'

def is_exotic_or_rare(color):
    rare_colors = [
        'nero ade', 'giallo taurus / nero ade', 'beluga', 'hotspur hide', 'adrenaline red',
        'pimento red', 'kyalami orange', 'titan black / quarzit', 'rioja red', 'pimento red w/ebony'
    ]
    return 'Exotic/Rare' if color.lower() in rare_colors else 'Common'

# Apply categorizations to the DataFrame columns
train_df['categorized_interior_color'] = train_df['int_col'].apply(categorize_interior_color)
train_df['luxurious_interior'] = train_df['int_col'].apply(is_luxurious)
train_df['light_or_dark_interior'] = train_df['int_col'].apply(is_light_or_dark)
train_df['two_tone_interior'] = train_df['int_col'].apply(is_two_tone)
train_df['exotic_or_rare_interior'] = train_df['int_col'].apply(is_exotic_or_rare)

test_df['categorized_interior_color'] = test_df['int_col'].apply(categorize_interior_color)
test_df['luxurious_interior'] = test_df['int_col'].apply(is_luxurious)
test_df['light_or_dark_interior'] = test_df['int_col'].apply(is_light_or_dark)
test_df['two_tone_interior'] = test_df['int_col'].apply(is_two_tone)
test_df['exotic_or_rare_interior'] = test_df['int_col'].apply(is_exotic_or_rare)

# %% [markdown]
# **Engine**

# %%
train_df["engine"].unique()
# Out:
# array(['375.0HP 3.5L V6 Cylinder Engine Gasoline Fuel',
#        '300.0HP 3.0L Straight 6 Cylinder Engine Gasoline Fuel',
#        '300.0HP 4.2L 8 Cylinder Engine Gasoline Fuel', ..., '3.0L',
#        '3.0 Liter GTDI',
#        '120.0HP 2.2L 4 Cylinder Engine Flex Fuel Capability'],
#       dtype=object)

# %%
import re

def extract_hp(engine_str):
    match = re.search(r'(\d+(\.\d+)?)HP', engine_str)
    return match.group(1) if match else None

def extract_displacement(engine_str):
    match = re.search(r'(\d+(\.\d+)?)L', engine_str)
    return match.group(1) if match else None

def extract_cylinders(engine_str):
    match = re.search(r'(\d+) Cylinder', engine_str)
    return match.group(1) if match else None

train_df['horsepower'] = train_df['engine'].apply(extract_hp)
train_df['displacement'] = train_df['engine'].apply(extract_displacement)
train_df['cylinders'] = train_df['engine'].apply(extract_cylinders)

test_df['horsepower'] = test_df['engine'].apply(extract_hp)
test_df['displacement'] = test_df['engine'].apply(extract_displacement)
test_df['cylinders'] = test_df['engine'].apply(extract_cylinders)

# %%
train_df.columns
# Out:
# Index(['id', 'brand', 'model', 'model_year', 'milage', 'fuel_type', 'engine',
#        'transmission', 'ext_col', 'int_col', 'accident', 'clean_title',
#        'price', 'categorized_ext_color', 'exotic_or_rare_ext',
#        'brightness_ext', 'metallic_finish_ext', 'finish_ext',
#        'categorized_interior_color', 'luxurious_interior',
#        'light_or_dark_interior', 'two_tone_interior',
#        'exotic_or_rare_interior', 'horsepower', 'displacement', 'cylinders'],
#       dtype='object')

# %% [markdown]
# **Get the new columns**

# %%
from datetime import datetime

# Assuming `df` is your DataFrame
# Current Year
current_year = datetime.now().year

# Calculate Car Age
train_df['car_age'] = current_year - train_df['model_year']
test_df['car_age'] = current_year - test_df['model_year']
# Calculate Mileage per Year
train_df['mileage_per_year'] = train_df['milage'] / train_df['car_age']
test_df['mileage_per_year'] = test_df['milage'] / test_df['car_age']

# %%
test_df.isnull().sum()
# Out:
# id                               0
# brand                            0
# model                            0
# model_year                       0
# milage                           0
# fuel_type                        0
# engine                           0
# transmission                     0
# ext_col                          0
# int_col                          0
# accident                         0
# clean_title                      0
# categorized_ext_color            0
# exotic_or_rare_ext               0
# brightness_ext                   0
# metallic_finish_ext              0
# finish_ext                       0
# categorized_interior_color       0
# luxurious_interior               0
# light_or_dark_interior           0
# two_tone_interior                0
# exotic_or_rare_interior          0
# horsepower                    2606
# displacement                   405
# cylinders                     2712
# car_age                          0
# mileage_per_year                 0
# dtype: int64

# %%
# Fill missing values with the string 'unspecified'
train_df['horsepower'] = train_df['horsepower'].fillna('unspecified')
train_df['displacement'] = train_df['displacement'].fillna('unspecified')
train_df['cylinders'] = train_df['cylinders'].fillna('unspecified')

# Fill missing values with the string 'unspecified'
test_df['horsepower'] = test_df['horsepower'].fillna('unspecified')
test_df['displacement'] = test_df['displacement'].fillna('unspecified')
test_df['cylinders'] = test_df['cylinders'].fillna('unspecified')

# %% [markdown]
# ## Feature selection

# %%
from sklearn.feature_selection import RFECV
from sklearn.model_selection import train_test_split
from catboost import CatBoostRegressor
from sklearn.metrics import mean_squared_error

# %%
categorical_features = [column for column in train_df.columns if train_df[column].dtype == 'object']

# Define target and features
target = 'price'
features = [col for col in train_df.columns if col != target]

# Split the data into features and target
X = train_df[features]
y = train_df[target]

# %%
# Define a function to fit the CatBoost model
model = CatBoostRegressor(
    iterations=1000,
    learning_rate=0.1,
    depth=10,
    cat_features=categorical_features,
    verbose=100
)

# Train the model
model.fit(X, y)
# Get feature importances
feature_importances = model.get_feature_importance()
feature_names = X.columns

# Create a DataFrame for visualization
importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': feature_importances})
importance_df = importance_df.sort_values(by='Importance', ascending=False)

# Plot feature importances
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 8))
sns.barplot(x='Importance', y='Feature', data=importance_df)
plt.title('Feature Importances from CatBoost')
plt.show()

# Display the top features
print(importance_df.head(20))
# Out:
# 0:	learn: 71970.8855342	total: 766ms	remaining: 12m 44s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[46], line 11
#       2 model = CatBoostRegressor(
#       3     iterations=1000,
#       4     learning_rate=0.1,
#    (...)
#       7     verbose=100
#       8 )
#      10 # Train the model
# ---> 11 model.fit(X, y)
#      12 # Get feature importances
#      13 feature_importances = model.get_feature_importance()
#
# File c:\Users\Spectra\kaggleX-challenge\.venv\Lib\site-packages\catboost\core.py:5827, in CatBoostRegressor.fit(self, X, y, cat_features, text_features, embedding_features, sample_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    5824 if 'loss_function' in params:
#    5825     CatBoostRegressor._check_is_compatible_loss(params['loss_function'])
# -> 5827 return self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline,
#    5828                  use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description,
#    5829                  verbose_eval, metric_period, silent, early_stopping_rounds,
#    5830                  save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#
# File c:\Users\Spectra\kaggleX-challenge\.venv\Lib\site-packages\catboost\core.py:2400, in CatBoost._fit(self, X, y, cat_features, text_features, embedding_features, pairs, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    2397 allow_clear_pool = train_params["allow_clear_pool"]
#    2399 with plot_wrapper(plot, plot_file, 'Training plots', [_get_train_dir(self.get_params())]):
# -> 2400     self._train(
#    2401         train_pool,
#    2402         train_params["eval_sets"],
#    2403         params,
#    2404         allow_clear_pool,
#    2405         train_params["init_model"]
#    2406     )
#    2408 # Have property feature_importance possibly set
#    2409 loss = self._object._get_loss_function_name()
#
# File c:\Users\Spectra\kaggleX-challenge\.venv\Lib\site-packages\catboost\core.py:1780, in _CatBoostBase._train(self, train_pool, test_pool, params, allow_clear_pool, init_model)
#    1779 def _train(self, train_pool, test_pool, params, allow_clear_pool, init_model):
# -> 1780     self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#    1781     self._set_trained_model_attributes()
#
# File _catboost.pyx:4833, in _catboost._CatBoost._train()
#
# File _catboost.pyx:4882, in _catboost._CatBoost._train()
#
# KeyboardInterrupt:

# %%
importance_df
# Out:
#                        Feature  Importance
# 4                       milage   12.069158
# 26            mileage_per_year   11.176382
# 1                        brand    9.125490
# 22                  horsepower    8.769477
# 6                       engine    8.498763
# 23                displacement    6.537089
# 3                   model_year    5.606469
# 2                        model    5.593159
# 0                           id    4.748462
# 12       categorized_ext_color    4.709910
# 25                     car_age    4.189571
# 24                   cylinders    3.843640
# 8                      ext_col    2.960601
# 17  categorized_interior_color    2.822719
# 9                      int_col    2.246275
# 7                 transmission    2.017453
# 5                    fuel_type    1.345022
# 16                  finish_ext    1.277472
# 19      light_or_dark_interior    0.808273
# 10                    accident    0.691434
# 14              brightness_ext    0.690013
# 21     exotic_or_rare_interior    0.081437
# 13          exotic_or_rare_ext    0.053049
# 15         metallic_finish_ext    0.051491
# 20           two_tone_interior    0.050479
# 18          luxurious_interior    0.036711
# 11                 clean_title    0.000000

# %%
selected_features = ['milage', 'mileage_per_year', 'brand', 'horsepower', 'engine',
                     'displacement', 'model_year', 'model', 'categorized_ext_color',
                     'car_age', 'cylinders', 'ext_col', 'categorized_interior_color', 'int_col']

# %%
X_new = X[selected_features]
y_new = y

X_train, X_val, y_train, y_val = train_test_split(X_new, y_new, test_size=0.1, random_state=42)

# %%
cat_features = [column for column in X_new.columns if X_new[column].dtype == 'object']

# %%
# Define the CatBoost model with regularization
model = CatBoostRegressor(iterations=2000,
                          learning_rate=0.1,
                          depth=6,
                          cat_features=cat_features,
                          loss_function='RMSE',
                          l2_leaf_reg=3,  
                          verbose=-1)

# Fit the model
model.fit(X_train, y_train)

# Make predictions
y_pred_train = model.predict(X_train)
y_pred_test = model.predict(X_val)

# Evaluate the model
train_rmse = mean_squared_error(y_train, y_pred_train, squared=False)
test_rmse = mean_squared_error(y_val, y_pred_test, squared=False)

print("Train RMSE:", train_rmse)
print("Test RMSE:", test_rmse)
# Out:
# 0:	learn: 74182.1389517	total: 156ms	remaining: 5m 12s
# 100:	learn: 66700.2305148	total: 17.8s	remaining: 5m 34s
# 200:	learn: 63900.6884392	total: 34s	remaining: 5m 4s
# 300:	learn: 61458.5100414	total: 51.7s	remaining: 4m 51s
# 400:	learn: 58991.8628095	total: 1m 9s	remaining: 4m 36s
# 500:	learn: 57546.7864312	total: 1m 27s	remaining: 4m 22s
# 600:	learn: 55752.3319789	total: 1m 44s	remaining: 4m 3s
# 700:	learn: 54597.6580196	total: 2m 2s	remaining: 3m 47s
# 800:	learn: 53648.3796503	total: 2m 20s	remaining: 3m 30s
# 900:	learn: 52824.0448935	total: 2m 38s	remaining: 3m 13s
# 1000:	learn: 51950.4896680	total: 2m 56s	remaining: 2m 56s
# 1100:	learn: 51019.0857105	total: 3m 25s	remaining: 2m 47s
# 1200:	learn: 50356.3433037	total: 3m 43s	remaining: 2m 28s
# 1300:	learn: 49592.6815651	total: 4m 1s	remaining: 2m 9s
# 1400:	learn: 48921.8309902	total: 4m 19s	remaining: 1m 50s
# 1500:	learn: 48360.8219833	total: 4m 37s	remaining: 1m 32s
# 1600:	learn: 47675.8908871	total: 4m 55s	remaining: 1m 13s
# 1700:	learn: 47101.0518969	total: 5m 13s	remaining: 55.1s
# 1800:	learn: 46575.7712596	total: 5m 30s	remaining: 36.6s
# 1900:	learn: 46083.2245131	total: 5m 49s	remaining: 18.2s
# 1999:	learn: 45539.5414262	total: 6m 6s	remaining: 0us
# Train RMSE: 55692.412072527164
# Test RMSE: 46451.849224720194
# c:\Users\Spectra\kaggleX-challenge\.venv\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# c:\Users\Spectra\kaggleX-challenge\.venv\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
# Define objective function for Optuna
import optuna

def objective(trial):
    # Define hyperparameters to be tuned
    params = {
        'iterations': trial.suggest_categorical('iterations', [1000, 2000, 3000]),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
        'depth': trial.suggest_int('depth', 3, 10),
        'l2_leaf_reg': trial.suggest_float('l2_leaf_reg', 1, 10),
        'min_data_in_leaf': trial.suggest_int('min_data_in_leaf', 1, 100),
        'subsample': trial.suggest_float('subsample', 0.05, 1.0),
        'colsample_bylevel': trial.suggest_float('colsample_bylevel', 0.1, 1.0)
    }

    # Create CatBoostRegressor
    model = CatBoostRegressor(loss_function='RMSE', **params, verbose=False)

    # Fit the model
    model.fit(X_train, y_train, cat_features=cat_features)

    # Make predictions
    y_pred = model.predict(X_val)

    # Calculate RMSE
    rmse = mean_squared_error(y_val, y_pred, squared=False)

    return rmse

# Perform hyperparameter optimization with Optuna
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=100)  

# Get the best hyperparameters
best_params = study.best_params

print("Best Parameters:", best_params)

# Create CatBoostRegressor with best hyperparameters
best_model = CatBoostRegressor(loss_function='RMSE', **best_params, verbose=False)

# Fit the best model
best_model.fit(X_train, y_train, cat_features=cat_features)

# Make predictions
y_pred_train = best_model.predict(X_train)
y_pred_test = best_model.predict(X_val)

# Evaluate the best model
train_rmse = mean_squared_error(y_train, y_pred_train, squared=False)
test_rmse = mean_squared_error(y_val, y_pred_test, squared=False)

print("Train RMSE:", train_rmse)
print("Test RMSE:", test_rmse)
# Out:
# [I 2024-06-10 17:10:05,273] A new study created in memory with name: no-name-15bc2307-b62c-4642-9c63-d9f222a280a0
# c:\Users\Spectra\kaggleX-challenge\.venv\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-06-10 17:11:13,229] Trial 0 finished with value: 44414.18634133035 and parameters: {'iterations': 1000, 'learning_rate': 0.012847872513178014, 'depth': 3, 'l2_leaf_reg': 1.2566626866235684, 'min_data_in_leaf': 83, 'subsample': 0.9738093020789005, 'colsample_bylevel': 0.8378850965223392}. Best is trial 0 with value: 44414.18634133035.
# c:\Users\Spectra\kaggleX-challenge\.venv\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-06-10 17:17:43,546] Trial 1 finished with value: 45571.02725475555 and parameters: {'iterations': 3000, 'learning_rate': 0.11377893696209113, 'depth': 5, 'l2_leaf_reg': 6.298925843816557, 'min_data_in_leaf': 12, 'subsample': 0.9630846685579689, 'colsample_bylevel': 0.3013387016902427}. Best is trial 0 with value: 44414.18634133035.
# c:\Users\Spectra\kaggleX-challenge\.venv\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-06-10 17:19:14,631] Trial 2 finished with value: 46543.37427397544 and parameters: {'iterations': 1000, 'learning_rate': 0.22268429445239166, 'depth': 5, 'l2_leaf_reg': 8.265237652315765, 'min_data_in_leaf': 18, 'subsample': 0.4301964628438293, 'colsample_bylevel': 0.34068665358744593}. Best is trial 0 with value: 44414.18634133035.
# c:\Users\Spectra\kaggleX-challenge\.venv\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-06-10 17:23:57,130] Trial 3 finished with value: 44332.863025482184 and parameters: {'iterations': 3000, 'learning_rate': 0.016956359981063134, 'depth': 4, 'l2_leaf_reg': 4.997631384429467, 'min_data_in_leaf': 1, 'subsample': 0.39318857726951306, 'colsample_bylevel': 0.47231224800164506}. Best is trial 3 with value: 44332.863025482184.
# c:\Users\Spectra\kaggleX-challenge\.venv\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-06-10 17:26:17,117] Trial 4 finished with value: 45142.34321923676 and parameters: {'iterations': 1000, 'learning_rate': 0.06236805151222486, 'depth': 5, 'l2_leaf_reg': 5.66586171646556, 'min_data_in_leaf': 7, 'subsample': 0.6659386927816715, 'colsample_bylevel': 0.6092649936040664}. Best is trial 3 with value: 44332.863025482184.
# c:\Users\Spectra\kaggleX-challenge\.venv\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-06-10 17:31:21,436] Trial 5 finished with value: 45540.112832351755 and parameters: {'iterations': 2000, 'learning_rate': 0.03634951669615666, 'depth': 6, 'l2_leaf_reg': 2.021196801527794, 'min_data_in_leaf': 70, 'subsample': 0.732550039212634, 'colsample_bylevel': 0.3284032892681238}. Best is trial 3 with value: 44332.863025482184.
# c:\Users\Spectra\kaggleX-challenge\.venv\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-06-10 17:47:30,600] Trial 6 finished with value: 44209.25753032694 and parameters: {'iterations': 3000, 'learning_rate': 0.018058736035085277, 'depth': 10, 'l2_leaf_reg': 6.532677710112542, 'min_data_in_leaf': 25, 'subsample': 0.9464716670158283, 'colsample_bylevel': 0.48204224435183307}. Best is trial 6 with value: 44209.25753032694.
# c:\Users\Spectra\kaggleX-challenge\.venv\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-06-10 17:51:40,084] Trial 7 finished with value: 45524.3739340734 and parameters: {'iterations': 1000, 'learning_rate': 0.10836461421109388, 'depth': 10, 'l2_leaf_reg': 6.04516543553213, 'min_data_in_leaf': 24, 'subsample': 0.056522632324152805, 'colsample_bylevel': 0.19174285700132743}. Best is trial 6 with value: 44209.25753032694.
# c:\Users\Spectra\kaggleX-challenge\.venv\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-06-10 17:52:39,869] Trial 8 finished with value: 44241.18087802989 and parameters: {'iterations': 1000, 'learning_rate': 0.04688298520243758, 'depth': 3, 'l2_leaf_reg': 6.496524031214944, 'min_data_in_leaf': 31, 'subsample': 0.6942763752046982, 'colsample_bylevel': 0.5929790436073858}. Best is trial 6 with value: 44209.25753032694.
# c:\Users\Spectra\kaggleX-challenge\.venv\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-06-10 17:55:13,958] Trial 9 finished with value: 44264.54757392834 and parameters: {'iterations': 2000, 'learning_rate': 0.010609218360780484, 'depth': 3, 'l2_leaf_reg': 2.2610932112121733, 'min_data_in_leaf': 8, 'subsample': 0.8420544053746449, 'colsample_bylevel': 0.49761327080367157}. Best is trial 6 with value: 44209.25753032694.
# c:\Users\Spectra\kaggleX-challenge\.venv\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-06-10 18:10:36,230] Trial 10 finished with value: 44618.40495119326 and parameters: {'iterations': 3000, 'learning_rate': 0.02461159143264884, 'depth': 10, 'l2_leaf_reg': 9.86487228896161, 'min_data_in_leaf': 47, 'subsample': 0.19499666622273415, 'colsample_bylevel': 0.9843380015424998}. Best is trial 6 with value: 44209.25753032694.
# c:\Users\Spectra\kaggleX-challenge\.venv\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-06-10 18:22:44,099] Trial 11 finished with value: 44912.25139934038 and parameters: {'iterations': 3000, 'learning_rate': 0.04482814004621209, 'depth': 8, 'l2_leaf_reg': 7.519538882102942, 'min_data_in_leaf': 37, 'subsample': 0.6272113943274457, 'colsample_bylevel': 0.6877364549425803}. Best is trial 6 with value: 44209.25753032694.
# c:\Users\Spectra\kaggleX-challenge\.venv\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-06-10 18:26:45,424] Trial 12 finished with value: 44309.02469390951 and parameters: {'iterations': 1000, 'learning_rate': 0.025229608297086873, 'depth': 8, 'l2_leaf_reg': 3.590241473130323, 'min_data_in_leaf': 35, 'subsample': 0.7930800895445702, 'colsample_bylevel': 0.7172937960021674}. Best is trial 6 with value: 44209.25753032694.
# c:\Users\Spectra\kaggleX-challenge\.venv\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-06-10 18:38:56,586] Trial 13 finished with value: 45339.72943742464 and parameters: {'iterations': 3000, 'learning_rate': 0.07480123162520685, 'depth': 8, 'l2_leaf_reg': 7.712813975252814, 'min_data_in_leaf': 61, 'subsample': 0.5438345828087445, 'colsample_bylevel': 0.4786932017107589}. Best is trial 6 with value: 44209.25753032694.
# c:\Users\Spectra\kaggleX-challenge\.venv\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-06-10 18:41:47,336] Trial 14 finished with value: 44205.042537809255 and parameters: {'iterations': 2000, 'learning_rate': 0.025457899180360965, 'depth': 7, 'l2_leaf_reg': 4.348856333153216, 'min_data_in_leaf': 29, 'subsample': 0.863542059911965, 'colsample_bylevel': 0.10899205226102437}. Best is trial 14 with value: 44205.042537809255.
# c:\Users\Spectra\kaggleX-challenge\.venv\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-06-10 18:46:45,931] Trial 15 finished with value: 43720.01302903373 and parameters: {'iterations': 2000, 'learning_rate': 0.023534866483893517, 'depth': 9, 'l2_leaf_reg': 4.028725000535012, 'min_data_in_leaf': 49, 'subsample': 0.8794404407705152, 'colsample_bylevel': 0.1363452246943897}. Best is trial 15 with value: 43720.01302903373.
# c:\Users\Spectra\kaggleX-challenge\.venv\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-06-10 18:49:58,537] Trial 16 finished with value: 43991.22794277454 and parameters: {'iterations': 2000, 'learning_rate': 0.02431035403651765, 'depth': 7, 'l2_leaf_reg': 4.256112195933371, 'min_data_in_leaf': 50, 'subsample': 0.8545757701760718, 'colsample_bylevel': 0.11074884347506685}. Best is trial 15 with value: 43720.01302903373.
# c:\Users\Spectra\kaggleX-challenge\.venv\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-06-10 18:54:21,619] Trial 17 finished with value: 44082.61652994367 and parameters: {'iterations': 2000, 'learning_rate': 0.03235406357230563, 'depth': 9, 'l2_leaf_reg': 3.5306846669856466, 'min_data_in_leaf': 99, 'subsample': 0.5354078551528976, 'colsample_bylevel': 0.1259114292940422}. Best is trial 15 with value: 43720.01302903373.
# c:\Users\Spectra\kaggleX-challenge\.venv\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-06-10 18:59:00,319] Trial 18 finished with value: 44387.23563702465 and parameters: {'iterations': 2000, 'learning_rate': 0.016743204144461683, 'depth': 7, 'l2_leaf_reg': 3.3725162029662954, 'min_data_in_leaf': 51, 'subsample': 0.8476243610060034, 'colsample_bylevel': 0.2311052453860363}. Best is trial 15 with value: 43720.01302903373.
# [W 2024-06-10 19:03:17,774] Trial 19 failed with parameters: {'iterations': 2000, 'learning_rate': 0.2963485942144454, 'depth': 9, 'l2_leaf_reg': 4.655574181335074, 'min_data_in_leaf': 69, 'subsample': 0.3708876745266847, 'colsample_bylevel': 0.24040161081709444} because of the following error: KeyboardInterrupt('').
# Traceback (most recent call last):
#   File "c:\Users\Spectra\kaggleX-challenge\.venv\Lib\site-packages\optuna\study\_optimize.py", line 196, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "C:\Users\Spectra\AppData\Local\Temp\ipykernel_33004\373275116.py", line 20, in objective
#     model.fit(X_train, y_train, cat_features=cat_features)
#   File "c:\Users\Spectra\kaggleX-challenge\.venv\Lib\site-packages\catboost\core.py", line 5827, in fit
#     return self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Spectra\kaggleX-challenge\.venv\Lib\site-packages\catboost\core.py", line 2400, in _fit
#     self._train(
#   File "c:\Users\Spectra\kaggleX-challenge\.venv\Lib\site-packages\catboost\core.py", line 1780, in _train
#     self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#   File "_catboost.pyx", line 4833, in _catboost._CatBoost._train
#   File "_catboost.pyx", line 4882, in _catboost._CatBoost._train
# KeyboardInterrupt
# [W 2024-06-10 19:03:17,812] Trial 19 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[37], line 32
#      30 # Perform hyperparameter optimization with Optuna
#      31 study = optuna.create_study(direction='minimize')
# ---> 32 study.optimize(objective, n_trials=100)
#      34 # Get the best hyperparameters
#      35 best_params = study.best_params
#
# File c:\Users\Spectra\kaggleX-challenge\.venv\Lib\site-packages\optuna\study\study.py:451, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     348 def optimize(
#     349     self,
#     350     func: ObjectiveFuncType,
#    (...)
#     357     show_progress_bar: bool = False,
#     358 ) -> None:
#     359     """Optimize an objective function.
#     360
#     361     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     449             If nested invocation of this method occurs.
#     450     """
# --> 451     _optimize(
#     452         study=self,
#     453         func=func,
#     454         n_trials=n_trials,
#     455         timeout=timeout,
#     456         n_jobs=n_jobs,
#     457         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     458         callbacks=callbacks,
#     459         gc_after_trial=gc_after_trial,
#     460         show_progress_bar=show_progress_bar,
#     461     )
#
# File c:\Users\Spectra\kaggleX-challenge\.venv\Lib\site-packages\optuna\study\_optimize.py:62, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      60 try:
#      61     if n_jobs == 1:
# ---> 62         _optimize_sequential(
#      63             study,
#      64             func,
#      65             n_trials,
#      66             timeout,
#      67             catch,
#      68             callbacks,
#      69             gc_after_trial,
#      70             reseed_sampler_rng=False,
#      71             time_start=None,
#      72             progress_bar=progress_bar,
#      73         )
#      74     else:
#      75         if n_jobs == -1:
#
# File c:\Users\Spectra\kaggleX-challenge\.venv\Lib\site-packages\optuna\study\_optimize.py:159, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     156         break
#     158 try:
# --> 159     frozen_trial = _run_trial(study, func, catch)
#     160 finally:
#     161     # The following line mitigates memory problems that can be occurred in some
#     162     # environments (e.g., services that use computing containers such as GitHub Actions).
#     163     # Please refer to the following PR for further details:
#     164     # https://github.com/optuna/optuna/pull/325.
#     165     if gc_after_trial:
#
# File c:\Users\Spectra\kaggleX-challenge\.venv\Lib\site-packages\optuna\study\_optimize.py:247, in _run_trial(study, func, catch)
#     240         assert False, "Should not reach."
#     242 if (
#     243     frozen_trial.state == TrialState.FAIL
#     244     and func_err is not None
#     245     and not isinstance(func_err, catch)
#     246 ):
# --> 247     raise func_err
#     248 return frozen_trial
#
# File c:\Users\Spectra\kaggleX-challenge\.venv\Lib\site-packages\optuna\study\_optimize.py:196, in _run_trial(study, func, catch)
#     194 with get_heartbeat_thread(trial._trial_id, study._storage):
#     195     try:
# --> 196         value_or_values = func(trial)
#     197     except exceptions.TrialPruned as e:
#     198         # TODO(mamu): Handle multi-objective cases.
#     199         state = TrialState.PRUNED
#
# Cell In[37], line 20, in objective(trial)
#      17 model = CatBoostRegressor(loss_function='RMSE', **params, verbose=False)
#      19 # Fit the model
# ---> 20 model.fit(X_train, y_train, cat_features=cat_features)
#      22 # Make predictions
#      23 y_pred = model.predict(X_val)
#
# File c:\Users\Spectra\kaggleX-challenge\.venv\Lib\site-packages\catboost\core.py:5827, in CatBoostRegressor.fit(self, X, y, cat_features, text_features, embedding_features, sample_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    5824 if 'loss_function' in params:
#    5825     CatBoostRegressor._check_is_compatible_loss(params['loss_function'])
# -> 5827 return self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline,
#    5828                  use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description,
#    5829                  verbose_eval, metric_period, silent, early_stopping_rounds,
#    5830                  save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#
# File c:\Users\Spectra\kaggleX-challenge\.venv\Lib\site-packages\catboost\core.py:2400, in CatBoost._fit(self, X, y, cat_features, text_features, embedding_features, pairs, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    2397 allow_clear_pool = train_params["allow_clear_pool"]
#    2399 with plot_wrapper(plot, plot_file, 'Training plots', [_get_train_dir(self.get_params())]):
# -> 2400     self._train(
#    2401         train_pool,
#    2402         train_params["eval_sets"],
#    2403         params,
#    2404         allow_clear_pool,
#    2405         train_params["init_model"]
#    2406     )
#    2408 # Have property feature_importance possibly set
#    2409 loss = self._object._get_loss_function_name()
#
# File c:\Users\Spectra\kaggleX-challenge\.venv\Lib\site-packages\catboost\core.py:1780, in _CatBoostBase._train(self, train_pool, test_pool, params, allow_clear_pool, init_model)
#    1779 def _train(self, train_pool, test_pool, params, allow_clear_pool, init_model):
# -> 1780     self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#    1781     self._set_trained_model_attributes()
#
# File _catboost.pyx:4833, in _catboost._CatBoost._train()
#
# File _catboost.pyx:4882, in _catboost._CatBoost._train()
#
# KeyboardInterrupt:

# %%
params = {'iterations': 2000, 'learning_rate': 0.023534866483893517, 'depth': 9, 'l2_leaf_reg': 4.028725000535012, 'min_data_in_leaf': 49, 'subsample': 0.8794404407705152, 'colsample_bylevel': 0.1363452246943897}
# Create CatBoostRegressor with best hyperparameters
best_model = CatBoostRegressor(loss_function='RMSE', **params, verbose=False)

# Fit the best model
best_model.fit(X_train, y_train, cat_features=cat_features)

# Make predictions
y_pred_train = best_model.predict(X_train)
y_pred_test = best_model.predict(X_val)

# Evaluate the best model
train_rmse = mean_squared_error(y_train, y_pred_train, squared=False)
test_rmse = mean_squared_error(y_val, y_pred_test, squared=False)
print("Train RMSE:", train_rmse)
print("Test RMSE:", test_rmse)
# Out:
# Train RMSE: 61355.36772181953
# Test RMSE: 43720.01302903373
# c:\Users\Spectra\kaggleX-challenge\.venv\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# c:\Users\Spectra\kaggleX-challenge\.venv\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
import lightgbm as lgb

# %%
params = {
    'num_iterations': 2000,
    'learning_rate': 0.023534866483893517,
    'max_depth': 9,
    'lambda_l2': 4.028725000535012,
    'min_data_in_leaf': 49,
    'subsample': 0.8794404407705152,
    'colsample_bytree': 0.1363452246943897,
    'metric': 'rmse',
}
for c in X_train.columns:
    col_type = X_train[c].dtype
    if col_type == 'object' or col_type.name == 'category':
        X_train[c] = X_train[c].astype('category')
        X_val[c] = X_val[c].astype('category')
        
fit_params={ 
            "eval_metric" : 'auc', 
            "eval_set" : [(X_val,y_val)],
            'categorical_feature': cat_features
           }
clf = lgb.LGBMRegressor(**params)

clf.fit(X_train, y_train, **fit_params)

preds = clf.predict(X_val)

train_rmse = mean_squared_error(y_train, clf.predict(X_train), squared=False)
test_rmse = mean_squared_error(y_val, preds, squared=False)

print("Train RMSE:", train_rmse)
print("Test RMSE:", test_rmse)
# Out:
# c:\Users\Spectra\kaggleX-challenge\.venv\Lib\site-packages\lightgbm\engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] min_data_in_leaf is set=49, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=49
# [LightGBM] [Warning] lambda_l2 is set=4.028725000535012, reg_lambda=0.0 will be ignored. Current value: lambda_l2=4.028725000535012
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Categorical features with more bins than the configured maximum bin number found.
# [LightGBM] [Warning] For categorical features, max_bin and max_bin_by_feature may be ignored with a large number of categories.
# [LightGBM] [Warning] min_data_in_leaf is set=49, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=49
# [LightGBM] [Warning] lambda_l2 is set=4.028725000535012, reg_lambda=0.0 will be ignored. Current value: lambda_l2=4.028725000535012
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000283 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3678
# [LightGBM] [Info] Number of data points in the train set: 48845, number of used features: 14
# [LightGBM] [Warning] min_data_in_leaf is set=49, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=49
# [LightGBM] [Warning] lambda_l2 is set=4.028725000535012, reg_lambda=0.0 will be ignored. Current value: lambda_l2=4.028725000535012
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Info] Start training from score 39297.021005
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] min_data_in_leaf is set=49, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=49
# [LightGBM] [Warning] lambda_l2 is set=4.028725000535012, reg_lambda=0.0 will be ignored. Current value: lambda_l2=4.028725000535012
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] min_data_in_leaf is set=49, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=49
# [LightGBM] [Warning] lambda_l2 is set=4.028725000535012, reg_lambda=0.0 will be ignored. Current value: lambda_l2=4.028725000535012
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# Train RMSE: 61919.46791484741
# Test RMSE: 44708.330712651696
# c:\Users\Spectra\kaggleX-challenge\.venv\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# c:\Users\Spectra\kaggleX-challenge\.venv\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
test_df_new = test_df[selected_features]

# %%
for c in test_df_new.columns:
    col_type = test_df_new[c].dtype
    if col_type == 'object' or col_type.name == 'category':
        test_df_new[c] = test_df_new[c].astype('category')
# Out:
# C:\Users\Spectra\AppData\Local\Temp\ipykernel_33004\1055674335.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df_new[c] = test_df_new[c].astype('category')
# C:\Users\Spectra\AppData\Local\Temp\ipykernel_33004\1055674335.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df_new[c] = test_df_new[c].astype('category')
# C:\Users\Spectra\AppData\Local\Temp\ipykernel_33004\1055674335.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df_new[c] = test_df_new[c].astype('category')
# C:\Users\Spectra\AppData\Local\Temp\ipykernel_33004\1055674335.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df_new[c] = test_df_new[c].astype('category')
# C:\Users\Spectra\AppData\Local\Temp\ipykernel_33004\1055674335.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df_new[c] = test_df_new[c].astype('category')
# C:\Users\Spectra\AppData\Local\Temp\ipykernel_33004\1055674335.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df_new[c] = test_df_new[c].astype('category')
# C:\Users\Spectra\AppData\Local\Temp\ipykernel_33004\1055674335.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df_new[c] = test_df_new[c].astype('category')
# C:\Users\Spectra\AppData\Local\Temp\ipykernel_33004\1055674335.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df_new[c] = test_df_new[c].astype('category')
# C:\Users\Spectra\AppData\Local\Temp\ipykernel_33004\1055674335.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df_new[c] = test_df_new[c].astype('category')
# C:\Users\Spectra\AppData\Local\Temp\ipykernel_33004\1055674335.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df_new[c] = test_df_new[c].astype('category')

# %%
predictions = clf.predict(test_df_new)
# Out:
# [LightGBM] [Warning] min_data_in_leaf is set=49, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=49
# [LightGBM] [Warning] lambda_l2 is set=4.028725000535012, reg_lambda=0.0 will be ignored. Current value: lambda_l2=4.028725000535012
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).

# %%
rounded_predictions = [round(pred, 3) for pred in predictions]
submission_df["price"] = rounded_predictions

# %%
submission_df.to_csv("data/submission.csv", index=False)

# %%
test_df
# Out:
#           id          brand  \
# 0      54273  Mercedes-Benz
# 1      54274          Lexus
# 2      54275  Mercedes-Benz
# 3      54276           Land
# 4      54277            BMW
# ...      ...            ...
# 36178  90451            GMC
# 36179  90452      Chevrolet
# 36180  90453         Toyota
# 36181  90454        Lincoln
# 36182  90455      Chevrolet
#
#                                                    model  model_year  milage  \
# 0                                          E-Class E 350        2014   73000
# 1                                            RX 350 Base        2015  128032
# 2                                          C-Class C 300        2015   51983
# 3      Rover Range Rover 5.0L Supercharged Autobiogra...        2018   29500
# 4                                           X6 xDrive40i        2020   90000
# ...                                                  ...         ...     ...
# 36178                                       Yukon Denali        2019    4500
# 36179                    Silverado 1500 Z71 Extended Cab        2004  185000
# 36180                                         Corolla LE        2011  116000
# 36181                                  Navigator Reserve        2019   39000
# 36182                                           Tahoe LT        2012  162731
#
#            fuel_type                                             engine  \
# 0           Gasoline      302.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 1           Gasoline      275.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 2           Gasoline       241.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 3           Gasoline       518.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 4           Gasoline  335.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
# ...              ...                                                ...
# 36178       Gasoline       420.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# 36179       Gasoline       295.0HP 5.3L 8 Cylinder Engine Gasoline Fuel
# 36180       Gasoline       132.0HP 1.8L 4 Cylinder Engine Gasoline Fuel
# 36181       Gasoline      450.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 36182  E85 Flex Fuel  320.0HP 5.3L 8 Cylinder Engine Flex Fuel Capab...
#
#       transmission ext_col int_col  ... categorized_interior_color  \
# 0        automatic   White   Beige  ...                      Beige
# 1        automatic  Silver   Black  ...                      Black
# 2        automatic    Blue   White  ...                      White
# 3        automatic   White   White  ...                      White
# 4        automatic   White   Black  ...                      Black
# ...            ...     ...     ...  ...                        ...
# 36178    automatic    Gray   Black  ...                      Black
# 36179    automatic     Red    Gray  ...                       Gray
# 36180       manual   Beige    Gray  ...                       Gray
# 36181    automatic   Black  Orange  ...                     Orange
# 36182    automatic   Black   Black  ...                      Black
#
#       luxurious_interior light_or_dark_interior two_tone_interior  \
# 0               Standard                  Light       Single-Tone
# 1               Standard                   Dark       Single-Tone
# 2               Standard                  Light       Single-Tone
# 3               Standard                  Light       Single-Tone
# 4               Standard                   Dark       Single-Tone
# ...                  ...                    ...               ...
# 36178           Standard                   Dark       Single-Tone
# 36179           Standard                   Dark       Single-Tone
# 36180           Standard                   Dark       Single-Tone
# 36181           Standard                   Dark       Single-Tone
# 36182           Standard                   Dark       Single-Tone
#
#       exotic_or_rare_interior horsepower displacement cylinders car_age  \
# 0                      Common      302.0          3.5         6      10
# 1                      Common      275.0          3.5         6       9
# 2                      Common      241.0          2.0         4       9
# 3                      Common      518.0          5.0         8       6
# 4                      Common      335.0          3.0         6       4
# ...                       ...        ...          ...       ...     ...
# 36178                  Common      420.0          6.2         8       5
# 36179                  Common      295.0          5.3         8      20
# 36180                  Common      132.0          1.8         4      13
# 36181                  Common      450.0          3.5         6       5
# 36182                  Common      320.0          5.3         8      12
#
#       mileage_per_year
# 0          7300.000000
# 1         14225.777778
# 2          5775.888889
# 3          4916.666667
# 4         22500.000000
# ...                ...
# 36178       900.000000
# 36179      9250.000000
# 36180      8923.076923
# 36181      7800.000000
# 36182     13560.916667
#
# [36183 rows x 27 columns]

# %%
import lightgbm as lgb

# Convert all object dtype columns to category dtype
for col in X_train.select_dtypes(include='object').columns:
    X_train[col] = X_train[col].astype('category')
    X_val[col] = X_val[col].astype('category')

def objective(trial):
    # Define the parameter search space
    param = {
        'objective': 'regression',
        'metric': 'rmse',
        'boosting_type': 'gbdt',
        'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.1),
        'num_leaves': trial.suggest_int('num_leaves', 20, 200),
        'max_depth': trial.suggest_int('max_depth', 3, 15),
        'min_child_samples': trial.suggest_int('min_child_samples', 5, 100),
        'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
        'reg_alpha': trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
        'reg_lambda': trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
        'verbose': -1
    }

    # Create the LightGBM dataset
    dtrain = lgb.Dataset(X_train, label=y_train, categorical_feature="auto")
    dvalid = lgb.Dataset(X_val, label=y_val, categorical_feature="auto", reference=dtrain)

    # Train the model
    gbm = lgb.train(param, dtrain, valid_sets=[dtrain, dvalid])

    # Predict and calculate the mean squared error
    preds = gbm.predict(X_val, num_iteration=gbm.best_iteration)
    rmse = mean_squared_error(y_val, preds, squared=False)
    return rmse

study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=20)

print('Best trial:')
trial = study.best_trial
print('  Value: {}'.format(trial.value))
print('  Params: ')
for key, value in trial.params.items():
    print('    {}: {}'.format(key, value))
# Get the best hyperparameters
best_params = study.best_params
print("Best Parameters:", best_params)

# %%
import lightgbm as lgb
# Convert all object dtype columns to category dtype
for col in X_train.select_dtypes(include='object').columns:
    X_train[col] = X_train[col].astype('category')
    X_val[col] = X_val[col].astype('category')
    
lgb_params = {
    'boosting_type': 'gbdt',  
    'objective': 'regression', 
    'metric': 'rmse', 
    'learning_rate': 0.02,
    'verbose': -1
}

 # Create the LightGBM dataset
dtrain = lgb.Dataset(X_train, label=y_train, categorical_feature="auto")
dvalid = lgb.Dataset(X_val, label=y_val, categorical_feature="auto", reference=dtrain)

# Train the model
gbm = lgb.train(lgb_params, dtrain, valid_sets=[dtrain, dvalid])

# Predict and calculate the mean squared error
preds = gbm.predict(X_val, num_iteration=gbm.best_iteration)
rmse = mean_squared_error(y_val, preds, squared=False)
print("Validation RMSE:", rmse)
